# %% [markdown]
# ## FILL IN YOUR NAME AND UTORID HERE

# %% [markdown]
# Assignment 4: Measuring the Period of Asteroid Steins
# ==============================================
#
# ## Before you begin
#
# Assuming you have loaded this file into your Jupyter Notebooks workspace, make sure to press the "play" button at the top of the page in each box. This will render the Markdown into nicely-formatted text.
#
# Select <span style="color:purple"> **View -> Show Line Numbers** </span> from the menu at the top to the screen. This will make line numbers appear in each of the blocks of code below. For this assignment we have added specific instuctuions such as "Edit the parameter on Line 5" to make it clear what is required. Unfortunately, you will need to check this again everytime you open this workbook, or refresh the JupyterHub.
#
# ## Introduction
#
# This Jupyter Notebook will serve as the template the third question on Assignment 4. You will be working through the content it contains and then filling in your own work in the spaces provided. In order to complete this assignment you will require the following (all of which will be provided to you):
#
# * The file Stein_mags.txt, which contains information on the magnitude of the asteroid Stein's versus time. More information is given on the data below.
# * The file Test_LightCurve2.csv. This contains the light curve of a Cepheid variable. You do not need it for you final answer/analysis related to asteroids, but you can experiment with it below to get a handle on the idea of phase folding a light curve (we have provided you with the true period for this object below)
#
#
# In the sections below, every individual sub-questions have been written in <span style="color:red"> Red Text </span>. Some questions require you to make edits to bits of code that we have provided, in which case we specify the specific lines you are required to edit. Other questions are short answer (paragraph) format, asking you to summarize what you learned from various portions of the activity. In cases where paragraph-stype answers are required, we have indicated where you should enter your responses in <span style="color:blue"> Blue Text.</span>
#
# Please reach out of you have any questions.
#
#
# ## Further Information on the Data
#
# In the file 'stein_mags.txt' are measurements of the apparent magnitude of asteroid Stein's, a target for the Rosetta mission. The observations were taken with the OSIRIS scientific camera that was part of the Rosetta spacecraft.
#
# Most famously, Rosetta orbited Comet 67P/Churyumov-Gerasimenko, and sent a lander, Philae, to the surface. Before that, it did a flyby of asteroid Stein's. Stein's is in the main asteroid belt. You can find more information on the Rosetta mission [here](esa.int/Science_Exploration/Space_Science/Rosetta).
#
# The data on asteroid Stein's were published in the journal article "Determination of the light curve of the Rosetta target asteroid (2867) Steins by the OSIRIS cameras onboard Rosetta" by Kuppers et al. (2007) ([link](https://www.aanda.org/articles/aa/full/2007/04/aa6694-06/aa6694-06.html)).
#
# The file contains two columns: date in Modified Julian Date (MJD), and apparent magnitude at a wavelength of 600 nm. A definition of MJD can be found [here](https://scienceworld.wolfram.com/astronomy/ModifiedJulianDate.html). Your goal is to use the data to estimate the rotational period of the asteroid.

# %% [markdown]
# #### <span style="color:red">QUESTION 3A:</span> Read in the Data File and Make a plot of magnitudes versus time
#
# Let's take a look at our data.
# * First, write a line of code in line 5 that will read in the data file 'stein_mags.txt' and then look at the result. Note: in previous assignments you were provided with a csv file. Here it is a tab-separated-values. If you are having trouble reading things in you should specify format='tab' in your ascii.read() command.
# * Then write bits of code in lines 8 and 9 so that they will select the column of data from the table that contains the observation dates and magnitudes for the asteroid
# * Then add code at the bottom of this cell to make a plot time on the date on the x-axis and magnitude on the y-axis. Please ensure that brighter measurements are on the TOP of the y-axis.
#
# Note if you are having trouble, try looking at the Python tutorial notebook provided for reference here (or some of your previous assignments).

# %%
from astropy.io import ascii
import numpy as np

# Read in the file (add a line of code here to read in the data file):
data = 

# select the columns for date and magnitudes:



# Add code here so that you plot date on the x-axis and magnitude on the y-axis.
import matplotlib.pyplot as plt
import matplotlib

# %% [markdown]
# #### <span style="color:red">QUESTION 3B:</span> "Phase fold" your light curve to perform an estimate of the period
#
# You should already be able to see an upward and downward trend in the light curve data above. This corresponds to the light curve getting brighter and fainter and it rotates around. We are now going to perform a slightly more quantitative estimate of the period.
#
# We are going to do this using a process called 'phase folding'. There is a separate page linked on the quercus assignment that describes what this is. Reivew this page now and then come back here.
#
# #### Experiment with the concept of Phase Folding on the Test Data
#
# Phase folding can be a tricky concept at first, but this will show you how it works, by using the test data in 'Test_LightCurve2.csv'. This is actually a light curve for a Cepheid variable star; so nothing to do with asteroids. But it will let you experiment before you work on the Stein light curve. In particular:
#
# * Now, spend some time experimenting with line 16 of the code. By editing this line you are testing whether a certain period works for the data you have. Here, line 17 will phase fold the data based on the period you entered, and then the data will be plotted by lines 20-26. See what happen when you run this on the test data with a period guess of 10 days. Now try with a period guess of 6.167. Do you see a difference. 6.167 is the true period of the star we have given you for test data. See how the plot changes as you slowly move away from this value.
# * Now try changing line 17 to read 12.334. This is twice the actual period of the star. Do you understand how you can tell this from the plot? The data points should be lined up with one another, but you should see two 'rises' and 'falls' of the stars brightness.
# * Finally, demonstrate what the plot looksl like if you select half the true period.
#
# One of the biggest differences between asteroids and Cepheid variable stars is that it is possible that the asteroid could rise and fall more than one in the same 'period' (it is not as regular and depends on the shape, etc. as it is turning). But you are looking again for when you see a pattern that then repeats again. Once you are done experiementing here and think you get the general idea, please go to the next cell.

# %%
from astropy.io import ascii
import matplotlib.pyplot as plt
import numpy as np

# Read in the file:
data_lc = ascii.read("Test_LightCurve2.csv",format='csv')

# Select the columns that you want to make a plot of:
time = data_lc['hjd']
magnitude = data_lc['mag']

# First, reset your time series so that it starts at 0 days. This will make things easier.
phase = time - time[0]

# Now try phase folding by a certain amount of time
period_test = 6.167 #period you want to try in days.
time_phased = (phase/period_test) % 1

#Now make a plot of this:
plt.figure(figsize=(6,3),dpi=100)
plt.plot(time_phased, magnitude,'bo' )

# Add axis labels. 
plt.xlabel('Phase',fontsize=14)
plt.ylabel('Magnitudes',fontsize=14)
plt.ylim([14,13])

# %% [markdown]
# #### Now try phase folding on the Stein light curve to determine a period.
#
# Now you should apply this method to the light curve of the Stein asteroid. It has a period somewhere in the range of 0.05 to 0.3 days.
#
# * In the code below edit lines 6 to point read in the data for Stein and 9 to 10 to select the columns columns for date and magnitude (you should be able to copy this from part A).
# * In practice, it would be **very** tedious to determine the period of your stars by purely by hand. We have therefore provided you some code to help you get close. This code essenetially tries phase folding your star by 15000 different periods between 0.05 and 0.3 days and tries to estimate how well it worked. Run the block of code and examine the plot that is produced in order to determine roughly what what your period lies in. Feel free to zoom in on the x-axis by modifying line 44. **Please see the quercus instructions for a description of what this is doing how to interpret this plot**.
# * Once you have a good idea of where your the period might lie, edit line 52 and uncomment lines 56-57 and 60-62 in order to to determine the period of your star by phase folding. Remember, what you are trying to do here is find the period where the overall 'scatter' in the phase folded light curve seems the lowest. Explore the entire area around any minima that appear in the first plot and if there are two minima that are similar depths in the first plot, explore them both (keeping in mind what was said above: asteroids can sometime have more complex light curves that go up/down more than once in one rotation period; so you are looking for where the overall scatter appears the smallest).
# * Once you think you have found the period with the lowest scatter, trying iterating with periods slighly above and below this in order to estimate your uncertainty on your period measurement. Once you are happy go to the next cell where you will report your final answer for this part.

# %%
from astropy.io import ascii
import matplotlib.pyplot as plt
import numpy as np

#First, point to the Stein dataset again: 


# select the columns for date and magnitudes (please keep these names so the rest of the code block below works)
#mjd = 
#mag = 

#This, reset your time series so that it starts at 0 days. This will make things easier.
phase = mjd - mjd[0]

##########################################################################################################
# Code to Test how well a large number of periods work in order to get you close to the right one.
##########################################################################################################

# Set up an array will a large number of periods that you want to test:
period_lowerlimit = 0.05
period_upperlimit = 0.3
number_of_tests = 15000
test_periods = np.linspace(period_lowerlimit,period_upperlimit,number_of_tests)
test_scatter = np.empty(number_of_tests)

# Set up a `for loop' that will loop over all the periods and check
for i in range(len(test_periods)):
    time_phased = (phase/test_periods[i]) % 1

    # Select the data points with phases between 0 and 0.05 if this is the correct period
    index = np.where(time_phased < 0.05)

    # Make sure we are basing this on real data:
    if len(index[0]) < 10:
        test_scatter[i] = np.nan
    else:
        test_scatter[i] = np.std(mag[index])

# Make a plot of the test period versus the scatter in values with phases between 0.0 and 0.05:
plt.figure(figsize=(10,5),dpi=100)
plt.plot(test_periods,test_scatter,marker='o')
plt.xlabel('Test Period (days)',fontsize=14)
plt.ylabel('Light Curve Scatter (mag)',fontsize=14)
#plt.xlim([0.05,0.3])
plt.show()

##########################################################################################################
# Code to phase fold and plot your data to examine results by eye:
##########################################################################################################

# Now try phase folding by a certain amount of time
period_test = 1 #period you want to try in days.
time_phased = (phase/period_test) % 1

#Now make a plot of this:
plt.figure(figsize=(10,5),dpi=100)
plt.plot(time_phased, mag,'o')

# Add axis labels. 
plt.xlabel('Phase',fontsize=14)
plt.ylabel('Magnitude',fontsize=14)
plt.ylim(-7.2,-7.6)
plt.show()

# %% [markdown]
# #### Report your final result
#
# Report your best estimate (and uncertainty) of the period of the Stein asteroid here.
#
# Note: in reality we don't use guess and check methods like this to determine periodicity in astronmy (even with help from graphs as shown above). There are other methods that involve e.g. taking the Forier transform of datasets to determine what frequencies are present in your data. But that would be a task for another course.

# %% [markdown]
# #### <span style="color:blue">INSERT YOUR ANSWER FOR QUESTION 3B HERE.</span>
